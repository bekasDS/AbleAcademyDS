# %% [markdown]
# Финальный Проект
# ---

# %% [markdown]
# Пожалуйста, создайте пакет **education**, который содержит следующие модули:
#
# 1. users
# 2. organizations
#
# Когда вы запускаете пакет напрямую, он должен показывать все модули, указанные в пакете.

# %% [markdown]
# ## Описание модулей приведено ниже:

# %% [markdown]
# ### Модуль **users** должен содержать классы **Human, Student(Human), Teacher(Human)**.
#
# 1. Класс **Human** должен содержать следующую информацию: имя, фамилию, возраст, пол, национальность, а также способы задания этой информации.
#
# >```
# > h1 = Human(name="John", familyname="Wick", age=35, gender="male", nationality="USA")
# > ```
#
# Список методов:
# > ```
# set_name()
# set_family()
# set_age()
# set_gender()
# set_nationality()
# get_info() # возвращает словарь с личной информацией об объекте
# > ```
#
# 2. Класс **Student** - это детский класс класса Human. Он должен содержать следующую информацию о каждом студенте: имя, фамилия, возраст, пол, национальность, название школы или университета, список предметов и соответствующие методы для установки этой информации.
#
#
# Список методов в дополнение к списку методов из родительского класса Human:
# > ```
# set_school()
# add_subject() # добавить предмет в список предметов
# > ```
#
#
# 3. Класс **Teacher** - это детский класс класса Human. Он должен содержать следующую информацию о каждом преподавателе: имя, фамилия, возраст, пол, национальность, название школы или университета, предмет преподавания и соответствующие методы для установки этой информации.
#
# Список методов в дополнение к списку методов из родительского класса Human:
# > ```
# set_school()
# add_subject() # добавить предмет преподаваемый учителем
# > ```
#
# * При непосредственном запуске модуля **users** напрямую должен отображаться список классов, а также списки методов соответствующих классов, приведенных в модуле.
#
# * Когда вы импортируете модуль, он должен показать, что модуль был успешно импортирован.
#
# ---

# %% [markdown]
# ### Модуль **organizations** должен содержать класс **School**.
#
# Класс **School** должен содержать следующую информацию: название или номер школы, адрес школы, номер телефона школы, электронный адрес учебного заведения, количество учеников, количество учителей, а также способы задания этой информации.
#
#
# >```
# > s1 = School(name="NIS", address="Astana, Kazakhstan", phone="999999", num_stud=1000, num_teachers=50)
# > ```
#
# Список методов:
# > ```
# set_name()
# set_address()
# set_phone()
# set_email()
# set_num_stud()
# set_num_teachers()
# add_student()
# add_teacher()
# get_info() # возвращает словарь с информацией про школу без личной информации студентов / преподавателей
# get_report() # создает отчет (файл "csv") с информацией о школе и о каждом ученике, а также о преподавателе в этой школе.
# > ```
#
# **Пожалуйста, сделайте правильный формат файла CSV (который вы считаете наиболее понятным)**
#
# * При непосредственном запуске модуля **organizations** напрямую должен отображаться список классов, а также списки методов соответствующих классов, приведенных в модуле.
#
# * Когда вы импортируете модуль, он должен показать, что модуль был успешно импортирован.
#
# ---

# %% [markdown]
# ### Что делать в jupyter notebook?
#
# В этом jupyter notebook, пожалуйста, проверьте все функциональные возможности вашего пакета. Как минимум создайте 2-3 школы, в каждой школе должно быть не менее 10 учеников (с разной информацией), а также как минимум 2 учителя разных предметов и личной информации. **Личная информация этих учеников, учителей и школ не должна быть правдивой (просто выдумайте).**
#
# **Пожалуйста, заархивируйте пакет и данный jupyter notebook вместе и отправьте архивный файл.**

# %%
# Ваш код:

# импорт пакета классов
from education import users as obj_1
from education import organizations as obj_2

# служебные модули с константами
import src.utils.listutils as cnst  # общие константы

# генерация фейковых списков для заполнения данными
# списки сформированы в отдельном модуле =>
from src.utils.listgenerator import (fake_common_human_list,        # люди (ученики и учителя)
                                     fake_common_school_list,       # школы
                                     fake_common_nation_list,       # национальность/гражданство/страна
                                     fake_common_subjects_list)     # предметы


import random
# Out:
# Модуль 'users.py' успешно импортирован
# Модуль 'organizations.py' успешно импортирован

# %% [markdown]
# ## **1.** Создание объектов через методы класса 'School'
# ### **1.1.** Школы

# %% [markdown]
# #### **<span style="color: red;">ПРИМЕЧАНИЕ</span>**
# ***
# 1. Для заполнения данных аргументов объектов, методов 'add_student' и 'add_teacher' используются списики с фейковыми данными.
#     * **fake_common_human_list**,        # люди (ученики и учителя)
#     * **fake_common_school_list**,       # школы
#     * **fake_common_nation_list**,       # национальность/гражданство/страна
#     * **fake_common_subjects_list**      # предметы
#
#
# 2. Создание списков происходит через цикл прохода соответствующих списков школ в блоке констант, определённых в одтельном модуле "<code>**./src/utils/generator.ipynb**</code>". Такой подход позволяет сделает произвольное множество сочетаний параметров, ограниченное модулем 'random'. Инструкции генерации описаны в генераторе.
#
# 3. Генерация произвольных чисел требуемых диапазонов сделано при помощи встроенного модуля '**random**'
#
# ***
#
# 4. **Изменения количества:**
#
#     * человек,
#     * учебных заведений,
#     * порогов для количества произвольных итераций
#
#     задаётся в отдельном модуле по адресу "<code>**./src/utils/listutils.py**</code>"
#
# ***
# 5. Так как заданы произвольные данные, при выводе в файлы отчётов могут повторяться названия предметов в пределах одного ученика. Этот артефакт не устранялся, по причине его несущественности в рамках проекта.
#
# 6. После беседы с преподавателем на воркшопе в Алматы, было принято решение принять вводимые данные <code>'students_count'</code> и <code>'teachers_count'</code> как максимально возможное количество человек в школе. Тогда устранится несогласованность между количеством добавляемых людей в школу через методы 'add_***'.

# %%
# СОЗДАНИЕ ШКОЛ

list_obj_school = []  # список созданных лбъектов школ

for i in fake_common_school_list:
    # print(common_school_list[str(i)])

    list_obj_school.append(obj_2.School(name=fake_common_school_list[str(i)]["name"],                      # название школы
                                        address=fake_common_school_list[str(i)]["address"],                # адрес
                                        phone=fake_common_school_list[str(i)]["phone"],                    # телефон
                                        email=fake_common_school_list[str(i)]["email"],                    # электронная почта
                                        students_count=fake_common_school_list[str(i)]["students_count"],  # МАКСИМАЛЬНОЕ количество учеников
                                        teachers_count=fake_common_school_list[str(i)]["teachers_count"]   # МАКСИМАЛЬНОЕ количество учителей
                                    )
                            )

# %%
# информация об объекте школа, созданного в предыдущем блоке
list_obj_school[0].get_info
# Out:
# {'id': '0',
#  'name': 'School №168',
#  'address': 'ш. Фадеева, д. 848 к. 5/8',
#  'phone': '89382421948',
#  'email': 'nikiforovvalerjan@example.net',
#  'students_count': '95',
#  'teachers_count': '8'}

# %% [markdown]
# ***
# ### **1.2.** Ученики &
# ### **1.3.** Учителя
# #### Пример создания УЧЕНИКОВ и УЧИТЕЛЕЙ для ранее созданных школ
#
# Люди добавляются в школы через цикл, методом класса:
# 1. Ученики => 'School.**add_student**',
# 2. Учители => 'School.**add_teacher**'.

# %%
# ДОБАВЛЕНИЕ УЧЕНИКОВ И УЧИТЕЛЕЙ В ШКОЛЫ

# список объектов класса 'Student' и 'Teacher'
list_obj_students, list_obj_teachers = [], []

# Создание записей для объектов 'Student' с распределением по школам
for ischool in range(len(fake_common_school_list)):  # проход по школам
    # название учебного заведения
    sname = fake_common_school_list[str(ischool)]["name"]

    # 1. СОЗДАНИЕ ОБЪЕКТОВ 'Teacher' ДЛЯ КОНКРЕТНОЙ ШКОЛЫ
    # счётчики
    numstud = numteach = 0
    
    for i in range(random.randrange(cnst.qutchr_1,cnst.qutchr_2)):
        # разбивка имени на ФИО
        names = fake_common_human_list[i]["name"].strip().split()
        
        # создание учителей
        list_obj_teachers.append(list_obj_school[ischool] \
                                .add_teacher(name=names[0],                                             # имя
                                            familyname=names[2],                                        # фамилия
                                            age=random.randrange(cnst.agetchr_1,cnst.agetchr_2),        # возраст
                                            gender=fake_common_human_list[i]["sex"],                    # пол
                                            nationality=random.choice(fake_common_nation_list),         # национальность
                                            subjects=random.choices(fake_common_subjects_list, k=2)     # предметы
                                            )
                                )
        
        numteach += 1


    # 2. СОЗДАНИЕ ОБЪЕКТОВ 'Student' ДЛЯ КОНКРЕТНОЙ ШКОЛЫ
    # добавляется случайное количество учеников в школу
    for i in range(random.randrange(cnst.qustud_1,cnst.qustud_2)):
        # разбивка имени на ФИО
        names = fake_common_human_list[i]["name"].strip().split()
        # создание учеников
        list_obj_students.append(list_obj_school[ischool] \
                                .add_student(name=names[0],                                                                          # имя
                                            familyname=names[2],                                                                     # фамилия
                                            age=random.randrange(cnst.agestud_1,cnst.agestud_2),                                     # возраст
                                            gender=fake_common_human_list[i]["sex"],                                                 # пол
                                            nationality=random.choice(fake_common_nation_list),                                      # национальность
                                            subjects=random.choices(fake_common_subjects_list, k=len(fake_common_subjects_list)//2)  # предметы
                                            )
                                )
    
        numstud += 1

    print(f"\nВсего добавлено в {sname} => {numstud} учеников и {numteach} учителей\n")
# Out:
# В 'School №168' добавлен новый учитель Измаил Самсонов, пол 'M', возрат 34, предметы ['Биология', 'Биология и валеология']
# В 'School №168' добавлен новый учитель Семенов Фролович, пол 'M', возрат 62, предметы ['Казахская литература', 'Русский язык']
# В 'School №168' добавлен новый учитель Шашков Фёдорович, пол 'M', возрат 34, предметы ['НВП', 'Основы обществознания']
# В 'School №168' добавлен новый учитель Степанов Аверьянович, пол 'M', возрат 61, предметы ['Практикум по физике', 'НВП']
# В 'School №168' добавлен новый учитель Лаврентьев Валерьевич, пол 'M', возрат 46, предметы ['Основы обществоведения', 'Математика']
# В 'School №168' добавлен новый учитель Панфил Ларионов, пол 'M', возрат 57, предметы ['Литература', 'История РК']
# В 'School №168' добавлен новый ученик Измаил Самсонов, пол 'M', возрат 13, предметы ['Валеология', 'Казахский язык', 'Биология', 'Черчение', 'Казахский язык', 'ОБЖ', 'Основы правоведения', 'Мировая художественная культура', 'Английский язык', 'Экология', 'Человек и общество', 'МХК', 'Хореография', 'МХК', 'Этика семьи', 'Этика семьи', 'Основы правоведения', 'Основы обществоведения', 'Зарубежная литература', 'История РК', 'Химия', 'Физкультура', 'Практикум по физике']
# В 'School №168' добавлен новый ученик Семенов Фролович, пол 'M', возрат 14, предметы ['Практикум по химии', 'Геометрия', 'ОИВТ', 'Черчение', 'Практикум по химии', 'Казахский язык', 'Русский язык', 'МХК', 'Основы правоведения', 'Основы правоведения', 'Черчение', 'История мира', 'Практика перевода', 'История мира', 'Литература', 'География', 'Русский язык', 'НВП', 'Биология и валеология', 'Практикум по физике', 'Астрономия', 'Хореография', 'Алгебра']
# В 'School №168' добавлен новый ученик Шашков Фёдорович, пол 'M', возрат 16, предметы ['Валеология', 'Мировая художественная культура', 'Химия', 'Геометрия', 'Казахский язык', 'Правоведение', 'Этика семьи', 'Практика перевода', 'История мира', 'МХК', 'Астрономия', 'Английский язык', 'Практикум по физике', 'Физика', 'Практикум по физике', 'Физкультура', 'Русский язык', 'Английский язык', 'Этика семьи', 'Литература', 'Основы обществоведения', 'Основы обществознания', 'Зарубежная литература']
# В 'School №168' добавлен новый ученик Степанов Аверьянович, пол 'M', возрат 10, предметы ['Экология', 'Зарубежная литература', 'Литература', 'Алгебра', 'ОБЖ', 'Экология', 'Всемирная история', 'Мировая художественная культура', 'Этика семьи', 'Мировая художественная культура', 'История мира', 'Алгебра', 'Астрономия', 'Валеология', 'Казахская литература', 'Русская литература', 'НВП', 'Информатика', 'Основы правоведения', 'ОБЖ', 'Английский язык', 'Казахская литература', 'Химия']
# В 'School №168' добавлен новый ученик Лаврентьев Валерьевич, пол 'M', возрат 11, предметы ['Русская литература', 'Физкультура', 'Практикум по химии', 'История Казахстана', 'Казахская литература', 'Основы обществознания', 'НВП', 'Казахская литература', 'История РК', 'Практикум перевода', 'Зарубежная литература', 'История мира', 'Физкультура', 'ОИВТ', 'Практикум по химии', 'Практикум по химии', 'Этика семьи', 'Валеология', 'Валеология', 'МХК', 'Практикум по химии', 'Практика перевода', 'Основы правоведения']
# В 'School №168' добавлен новый ученик Панфил Ларионов, пол 'M', возрат 16, предметы ['Казахский язык', 'Алгебра', 'Геометрия', 'Человек и общество', 'Человек и общество', 'НВП', 'Информатика', 'МХК', 'География', 'Человек и общество', 'История РК', 'Экология', 'Астрономия', 'Химия', 'Этика семьи', 'История Казахстана', 'Информатика', 'Мировая художественная культура', 'Информатика', 'Литература', 'Человек и общество', 'Практикум по химии', 'ОИВТ']
# В 'School №168' добавлен новый ученик Нестор Семенов, пол 'M', возрат 16, предметы ['История Казахстана', 'Практикум по химии', 'Всемирная история', 'Практикум перевода', 'ОИВТ', 'Английский язык', 'География', 'Физика', 'Мировая художественная культура', 'Биология', 'История мира', 'Правоведение', 'Русская литература', 'Основы обществоведения', 'Биология и валеология', 'Физика', 'Валеология', 'Практика перевода', 'Геометрия', 'Мировая художественная культура', 'Практикум перевода', 'Мировая художественная культура', 'Валеология']
# В 'School №168' добавлен новый ученик Вишнякова Аскольдовна, пол 'F', возрат 10, предметы ['Хореография', 'Зарубежная литература', 'Основы обществознания', 'Хореография', 'Информатика', 'ОБЖ', 'ОИВТ', 'Биология', 'География', 'Основы обществознания', 'Экология', 'ОИВТ', 'Хореография', 'Практика перевода', 'Литература', 'Русский язык', 'Русский язык', 'Русская литература', 'МХК', 'Всемирная история', 'Мировая художественная культура', 'Математика', 'Всемирная история']
# В 'School №168' добавлен новый ученик Кондратьев Васильевич, пол 'M', возрат 15, предметы ['Русский язык', 'МХК', 'Зарубежная литература', 'История Казахстана', 'Основы обществоведения', 'Казахский язык', 'Алгебра', 'Информатика', 'Алгебра', 'Практикум перевода', 'Человек и общество', 'Казахская литература', 'Этика семьи', 'Практика перевода', 'Практикум перевода', 'История РК', 'Казахская литература', 'Физкультура', 'Английский язык', 'Мировая художественная культура', 'Биология', 'Валеология', 'Русский язык']
# В 'School №168' добавлен новый ученик Ирина Наумова, пол 'F', возрат 12, предметы ['Русский язык', 'МХК', 'Хореография', 'МХК', 'Литература', 'НВП', 'Биология и валеология', 'Английский язык', 'Экология', 'Казахский язык', 'Мировая художественная культура', 'География', 'Русская литература', 'Мировая художественная культура', 'Черчение', 'Русская литература', 'Практика перевода', 'Информатика', 'Математика', 'Литература', 'Всемирная история', 'Мировая художественная культура', 'Всемирная история']
# В 'School №168' добавлен новый ученик Самойлов Владиславович, пол 'M', возрат 13, предметы ['Практикум по физике', 'История РК', 'Основы правоведения', 'Правоведение', 'Практикум по физике', 'Русский язык', 'Мировая художественная культура', 'Литература', 'Литература', 'Хореография', 'Экология', 'Литература', 'Биология', 'ОИВТ', 'Основы обществознания', 'НВП', 'Этика семьи', 'Алгебра', 'Геометрия', 'История РК', 'Хореография', 'Геометрия', 'Практикум перевода']
# В 'School №168' добавлен новый ученик Зосима Ситников, пол 'M', возрат 12, предметы ['Зарубежная литература', 'НВП', 'Мировая художественная культура', 'Человек и общество', 'Основы правоведения', 'Этика семьи', 'Основы обществоведения', 'Казахский язык', 'Этика семьи', 'Этика семьи', 'Русский язык', 'Основы обществоведения', 'Русская литература', 'ОИВТ', 'Астрономия', 'Биология и валеология', 'Русская литература', 'Казахская литература', 'Биология', 'Мировая художественная культура', 'Алгебра', 'Биология и валеология', 'Практика перевода']
#
# Всего добавлено в School №168 => 12 учеников и 6 учителей
#
# В 'School №51' добавлен новый учитель Измаил Самсонов, пол 'M', возрат 41, предметы ['МХК', 'НВП']
# В 'School №51' добавлен новый учитель Семенов Фролович, пол 'M', возрат 55, предметы ['ОБЖ', 'Этика семьи']
# В 'School №51' добавлен новый учитель Шашков Фёдорович, пол 'M', возрат 46, предметы ['ОИВТ', 'Всемирная история']
# В 'School №51' добавлен новый учитель Степанов Аверьянович, пол 'M', возрат 61, предметы ['Казахская литература', 'История мира']
# В 'School №51' добавлен новый учитель Лаврентьев Валерьевич, пол 'M', возрат 60, предметы ['МХК', 'Валеология']
# В 'School №51' добавлен новый учитель Панфил Ларионов, пол 'M', возрат 28, предметы ['Хореография', 'Геометрия']
# В 'School №51' добавлен новый учитель Нестор Семенов, пол 'M', возрат 59, предметы ['Математика', 'Человек и общество']
# В 'School №51' добавлен новый учитель Вишнякова Аскольдовна, пол 'F', возрат 46, предметы ['Русский язык', 'Казахская литература']
# В 'School №51' добавлен новый ученик Измаил Самсонов, пол 'M', возрат 11, предметы ['Мировая художественная культура', 'Правоведение', 'НВП', 'ОИВТ', 'Физкультура', 'МХК', 'Хореография', 'МХК', 'Биология и валеология', 'География', 'Всемирная история', 'История мира', 'Валеология', 'НВП', 'Физкультура', 'История Казахстана', 'История мира', 'Геометрия', 'Геометрия', 'Зарубежная литература', 'ОБЖ', 'Мировая художественная культура', 'Хореография']
# В 'School №51' добавлен новый ученик Семенов Фролович, пол 'M', возрат 11, предметы ['МХК', 'Астрономия', 'Хореография', 'Физкультура', 'Человек и общество', 'Валеология', 'Физкультура', 'Основы обществознания', 'Практикум по химии', 'Правоведение', 'Человек и общество', 'Хореография', 'Химия', 'Практика перевода', 'Валеология', 'МХК', 'Мировая художественная культура', 'Алгебра', 'МХК', 'Казахский язык', 'Черчение', 'Хореография', 'История мира']
# В 'School №51' добавлен новый ученик Шашков Фёдорович, пол 'M', возрат 15, предметы ['Экология', 'Алгебра', 'История РК', 'Практика перевода', 'История РК', 'Этика семьи', 'История Казахстана', 'МХК', 'Основы обществознания', 'ОБЖ', 'Практика перевода', 'Черчение', 'Человек и общество', 'Хореография', 'Литература', 'МХК', 'Практикум по химии', 'География', 'Казахская литература', 'Геометрия', 'Мировая художественная культура', 'Валеология', 'Русская литература']
# В 'School №51' добавлен новый ученик Степанов Аверьянович, пол 'M', возрат 15, предметы ['История Казахстана', 'Математика', 'Практикум по химии', 'НВП', 'Казахская литература', 'Биология', 'Геометрия', 'Практика перевода', 'Основы обществоведения', 'НВП', 'ОИВТ', 'Основы правоведения', 'Правоведение', 'МХК', 'НВП', 'НВП', 'Геометрия', 'НВП', 'Практикум по физике', 'Основы правоведения', 'Этика семьи', 'История мира', 'Математика']
# В 'School №51' добавлен новый ученик Лаврентьев Валерьевич, пол 'M', возрат 14, предметы ['Практика перевода', 'Математика', 'Этика семьи', 'Биология и валеология', 'НВП', 'ОИВТ', 'МХК', 'Основы обществоведения', 'ОБЖ', 'Этика семьи', 'Русский язык', 'Физкультура', 'Практикум по физике', 'ОИВТ', 'Геометрия', 'Геометрия', 'НВП', 'История РК', 'Основы обществознания', 'МХК', 'История Казахстана', 'Алгебра', 'Практикум по физике']
# В 'School №51' добавлен новый ученик Панфил Ларионов, пол 'M', возрат 15, предметы ['НВП', 'Этика семьи', 'Основы обществознания', 'Информатика', 'Физкультура', 'Русский язык', 'Валеология', 'Этика семьи', 'ОИВТ', 'Русский язык', 'МХК', 'МХК', 'Этика семьи', 'Геометрия', 'Основы обществоведения', 'Физика', 'Практикум перевода', 'Физкультура', 'Практикум по физике', 'Хореография', 'Геометрия', 'Казахский язык', 'Биология и валеология']
# В 'School №51' добавлен новый ученик Нестор Семенов, пол 'M', возрат 11, предметы ['Зарубежная литература', 'Геометрия', 'Мировая художественная культура', 'НВП', 'Казахский язык', 'Биология и валеология', 'Этика семьи', 'Основы обществознания', 'Английский язык', 'Биология и валеология', 'Этика семьи', 'Русский язык', 'ОИВТ', 'ОИВТ', 'История Казахстана', 'Мировая художественная культура', 'ОИВТ', 'Астрономия', 'Биология и валеология', 'Экология', 'НВП', 'НВП', 'История РК']
# В 'School №51' добавлен новый ученик Вишнякова Аскольдовна, пол 'F', возрат 15, предметы ['ОИВТ', 'ОИВТ', 'Русская литература', 'Основы правоведения', 'Алгебра', 'Правоведение', 'Практика перевода', 'ОИВТ', 'Практикум перевода', 'МХК', 'Хореография', 'Биология и валеология', 'Английский язык', 'Казахский язык', 'Литература', 'Физика', 'Практика перевода', 'Хореография', 'Геометрия', 'Валеология', 'Основы правоведения', 'География', 'МХК']
# В 'School №51' добавлен новый ученик Кондратьев Васильевич, пол 'M', возрат 10, предметы ['Алгебра', 'География', 'ОБЖ', 'ОИВТ', 'Этика семьи', 'Хореография', 'Практикум по химии', 'Практикум по физике', 'МХК', 'Литература', 'Хореография', 'МХК', 'Алгебра', 'Математика', 'Литература', 'Русская литература', 'Математика', 'История Казахстана', 'Валеология', 'Литература', 'НВП', 'Экология', 'Зарубежная литература']
# В 'School №51' добавлен новый ученик Ирина Наумова, пол 'F', возрат 11, предметы ['ОБЖ', 'Английский язык', 'История Казахстана', 'Практикум по физике', 'Практикум по химии', 'НВП', 'Этика семьи', 'Астрономия', 'Казахская литература', 'Черчение', 'Биология и валеология', 'Основы правоведения', 'Практикум перевода', 'Основы обществоведения', 'Человек и общество', 'НВП', 'Алгебра', 'МХК', 'Английский язык', 'Правоведение', 'Астрономия', 'Хореография', 'Практика перевода']
# В 'School №51' добавлен новый ученик Самойлов Владиславович, пол 'M', возрат 10, предметы ['Правоведение', 'Химия', 'Практикум по химии', 'Казахский язык', 'Литература', 'Практикум перевода', 'Математика', 'Практикум перевода', 'Основы правоведения', 'Казахский язык', 'Русская литература', 'Русская литература', 'Практикум по физике', 'Всемирная история', 'Русский язык', 'История мира', 'ОБЖ', 'История РК', 'История Казахстана', 'Английский язык', 'Хореография', 'Экология', 'Черчение']
# В 'School №51' добавлен новый ученик Зосима Ситников, пол 'M', возрат 13, предметы ['Человек и общество', 'Валеология', 'Практика перевода', 'Хореография', 'Основы правоведения', 'Этика семьи', 'ОИВТ', 'НВП', 'Хореография', 'Зарубежная литература', 'Практика перевода', 'Всемирная история', 'Мировая художественная культура', 'Хореография', 'Экология', 'Информатика', 'Практика перевода', 'НВП', 'Практикум по физике', 'Мировая художественная культура', 'Русская литература', 'Казахская литература', 'Основы обществознания']
# В 'School №51' добавлен новый ученик Волкова Альбертовна, пол 'F', возрат 16, предметы ['Химия', 'Казахский язык', 'НВП', 'НВП', 'Черчение', 'Экология', 'Литература', 'МХК', 'Человек и общество', 'Информатика', 'История Казахстана', 'Химия', 'Биология и валеология', 'Хореография', 'Правоведение', 'Алгебра', 'Физика', 'Правоведение', 'Валеология', 'НВП', 'География', 'МХК', 'Геометрия']
# В 'School №51' добавлен новый ученик Русакова Павловна, пол 'F', возрат 15, предметы ['Физика', 'Биология и валеология', 'Русский язык', 'Мировая художественная культура', 'Всемирная история', 'Этика семьи', 'Физика', 'Основы обществоведения', 'Экология', 'МХК', 'МХК', 'Основы обществоведения', 'Основы правоведения', 'Математика', 'Биология', 'Физкультура', 'Алгебра', 'Практика перевода', 'Биология и валеология', 'Геометрия', 'Алгебра', 'История РК', 'Биология']
#
# Всего добавлено в School №51 => 14 учеников и 8 учителей
#
# В 'School №105' добавлен новый учитель Измаил Самсонов, пол 'M', возрат 63, предметы ['Человек и общество', 'Русский язык']
# В 'School №105' добавлен новый учитель Семенов Фролович, пол 'M', возрат 64, предметы ['Практикум перевода', 'Казахский язык']
# В 'School №105' добавлен новый учитель Шашков Фёдорович, пол 'M', возрат 46, предметы ['Химия', 'Черчение']
# В 'School №105' добавлен новый ученик Измаил Самсонов, пол 'M', возрат 13, предметы ['Экология', 'Геометрия', 'Мировая художественная культура', 'Экология', 'Физика', 'История Казахстана', 'Астрономия', 'МХК', 'Информатика', 'Химия', 'История мира', 'История РК', 'Алгебра', 'Практикум перевода', 'Хореография', 'История мира', 'Основы обществознания', 'Экология', 'История Казахстана', 'Биология и валеология', 'Математика', 'Человек и общество', 'Этика семьи']
# В 'School №105' добавлен новый ученик Семенов Фролович, пол 'M', возрат 16, предметы ['Литература', 'НВП', 'МХК', 'Основы обществоведения', 'Физкультура', 'Русский язык', 'Хореография', 'История мира', 'Хореография', 'Основы обществоведения', 'ОИВТ', 'Русский язык', 'Валеология', 'Основы обществознания', 'Биология', 'Практикум перевода', 'Хореография', 'Валеология', 'Информатика', 'История мира', 'Астрономия', 'Всемирная история', 'Практика перевода']
# В 'School №105' добавлен новый ученик Шашков Фёдорович, пол 'M', возрат 11, предметы ['Казахская литература', 'Практикум по физике', 'История мира', 'Русская литература', 'МХК', 'Литература', 'ОИВТ', 'Зарубежная литература', 'География', 'Экология', 'Этика семьи', 'Казахский язык', 'Черчение', 'Практикум по химии', 'История мира', 'Человек и общество', 'Мировая художественная культура', 'Экология', 'История РК', 'Хореография', 'Мировая художественная культура', 'Мировая художественная культура', 'Физика']
# В 'School №105' добавлен новый ученик Степанов Аверьянович, пол 'M', возрат 12, предметы ['МХК', 'Основы правоведения', 'Физика', 'Хореография', 'Черчение', 'Всемирная история', 'Этика семьи', 'Физкультура', 'Физкультура', 'Валеология', 'Астрономия', 'Казахский язык', 'ОИВТ', 'Практикум по химии', 'География', 'Основы обществознания', 'Биология и валеология', 'Правоведение', 'История РК', 'История Казахстана', 'Практикум по химии', 'Практикум по химии', 'История мира']
# В 'School №105' добавлен новый ученик Лаврентьев Валерьевич, пол 'M', возрат 14, предметы ['Биология', 'Русский язык', 'Физкультура', 'Физкультура', 'Этика семьи', 'География', 'Валеология', 'Практика перевода', 'Человек и общество', 'Химия', 'Биология и валеология', 'НВП', 'Мировая художественная культура', 'ОИВТ', 'История мира', 'Мировая художественная культура', 'Основы правоведения', 'Казахский язык', 'Физика', 'Казахский язык', 'Математика', 'Русский язык', 'Русская литература']
# В 'School №105' добавлен новый ученик Панфил Ларионов, пол 'M', возрат 11, предметы ['Черчение', 'Русская литература', 'Всемирная история', 'МХК', 'Человек и общество', 'Этика семьи', 'Русский язык', 'Валеология', 'Практикум по физике', 'Русский язык', 'Астрономия', 'Зарубежная литература', 'Математика', 'Геометрия', 'Этика семьи', 'Литература', 'Алгебра', 'Основы обществознания', 'Мировая художественная культура', 'Биология', 'Хореография', 'Астрономия', 'Основы обществоведения']
# В 'School №105' добавлен новый ученик Нестор Семенов, пол 'M', возрат 16, предметы ['История Казахстана', 'Алгебра', 'Основы правоведения', 'Основы обществоведения', 'МХК', 'Основы правоведения', 'Казахский язык', 'ОИВТ', 'Всемирная история', 'ОБЖ', 'Валеология', 'Всемирная история', 'Правоведение', 'Физкультура', 'Черчение', 'Этика семьи', 'Казахский язык', 'Экология', 'Биология', 'Литература', 'Основы обществознания', 'Литература', 'Биология и валеология']
# В 'School №105' добавлен новый ученик Вишнякова Аскольдовна, пол 'F', возрат 12, предметы ['Математика', 'География', 'Мировая художественная культура', 'Черчение', 'Математика', 'Практикум по физике', 'Этика семьи', 'Основы правоведения', 'ОБЖ', 'Практикум по физике', 'Правоведение', 'Физкультура', 'НВП', 'Геометрия', 'История РК', 'Английский язык', 'Практика перевода', 'Всемирная история', 'Математика', 'История РК', 'Биология и валеология', 'Практикум по физике', 'Валеология']
# В 'School №105' добавлен новый ученик Кондратьев Васильевич, пол 'M', возрат 14, предметы ['Правоведение', 'ОБЖ', 'Экология', 'Всемирная история', 'Геометрия', 'Английский язык', 'Экология', 'Казахская литература', 'ОИВТ', 'НВП', 'Правоведение', 'География', 'ОБЖ', 'Практикум перевода', 'МХК', 'Русский язык', 'Основы обществоведения', 'ОБЖ', 'Черчение', 'МХК', 'Астрономия', 'История мира', 'История мира']
# В 'School №105' добавлен новый ученик Ирина Наумова, пол 'F', возрат 10, предметы ['Информатика', 'Физика', 'Практика перевода', 'Мировая художественная культура', 'Основы правоведения', 'НВП', 'Основы обществознания', 'Этика семьи', 'Биология', 'Геометрия', 'Геометрия', 'Основы правоведения', 'Математика', 'Казахский язык', 'Всемирная история', 'Астрономия', 'Практикум перевода', 'Мировая художественная культура', 'Русский язык', 'Информатика', 'Английский язык', 'Человек и общество', 'Казахский язык']
# В 'School №105' добавлен новый ученик Самойлов Владиславович, пол 'M', возрат 12, предметы ['Мировая художественная культура', 'Литература', 'Геометрия', 'История РК', 'Химия', 'Мировая художественная культура', 'Русская литература', 'Хореография', 'Литература', 'Практикум по физике', 'Английский язык', 'НВП', 'Основы обществоведения', 'Мировая художественная культура', 'Русская литература', 'Валеология', 'Практикум по химии', 'Английский язык', 'Литература', 'Валеология', 'Практика перевода', 'Черчение', 'Физика']
# В 'School №105' добавлен новый ученик Зосима Ситников, пол 'M', возрат 12, предметы ['МХК', 'ОБЖ', 'Русская литература', 'МХК', 'Практикум перевода', 'Алгебра', 'Математика', 'Хореография', 'Астрономия', 'Хореография', 'Черчение', 'МХК', 'Основы обществоведения', 'Человек и общество', 'Основы правоведения', 'ОИВТ', 'Казахский язык', 'Мировая художественная культура', 'Хореография', 'История Казахстана', 'Русская литература', 'Зарубежная литература', 'Физкультура']
# В 'School №105' добавлен новый ученик Волкова Альбертовна, пол 'F', возрат 13, предметы ['Практикум по физике', 'Практикум по химии', 'История РК', 'Этика семьи', 'Экология', 'МХК', 'Зарубежная литература', 'Человек и общество', 'Правоведение', 'ОБЖ', 'История Казахстана', 'Основы обществоведения', 'Практикум по химии', 'Основы правоведения', 'Всемирная история', 'Основы правоведения', 'Хореография', 'Практика перевода', 'История мира', 'Черчение', 'Биология', 'Практика перевода', 'История мира']
# В 'School №105' добавлен новый ученик Русакова Павловна, пол 'F', возрат 16, предметы ['Хореография', 'Физкультура', 'ОИВТ', 'Русский язык', 'Экология', 'Черчение', 'Биология и валеология', 'Практикум перевода', 'Всемирная история', 'Практикум по химии', 'Хореография', 'Английский язык', 'Практикум перевода', 'Всемирная история', 'Биология и валеология', 'НВП', 'Литература', 'Биология', 'Правоведение', 'Этика семьи', 'Астрономия', 'Мировая художественная культура', 'История мира']
# В 'School №105' добавлен новый ученик Попова Сергеевна, пол 'F', возрат 13, предметы ['НВП', 'Геометрия', 'История мира', 'ОБЖ', 'Валеология', 'Литература', 'Практика перевода', 'Мировая художественная культура', 'НВП', 'География', 'ОБЖ', 'Практика перевода', 'Правоведение', 'Физкультура', 'История Казахстана', 'НВП', 'МХК', 'Валеология', 'МХК', 'Казахская литература', 'Этика семьи', 'Правоведение', 'География']
# В 'School №105' добавлен новый ученик Виктория Лебедева, пол 'F', возрат 14, предметы ['МХК', 'Мировая художественная культура', 'Русский язык', 'Человек и общество', 'МХК', 'Хореография', 'Основы обществоведения', 'Литература', 'Физкультура', 'Биология и валеология', 'Геометрия', 'Мировая художественная культура', 'Правоведение', 'Русский язык', 'Экология', 'Этика семьи', 'Хореография', 'Математика', 'Правоведение', 'Мировая художественная культура', 'Практикум по физике', 'Литература', 'Зарубежная литература']
# В 'School №105' добавлен новый ученик Назар Исаев, пол 'M', возрат 14, предметы ['Этика семьи', 'Биология', 'Химия', 'Алгебра', 'НВП', 'Мировая художественная культура', 'Мировая художественная культура', 'Физика', 'Алгебра', 'Математика', 'Математика', 'Практикум перевода', 'Черчение', 'География', 'Зарубежная литература', 'МХК', 'Физкультура', 'Практика перевода', 'История мира', 'Геометрия', 'Практикум по химии', 'Биология', 'Биология и валеология']
# В 'School №105' добавлен новый ученик Авксентий Воронцов, пол 'M', возрат 15, предметы ['МХК', 'Геометрия', 'История Казахстана', 'ОИВТ', 'Основы обществоведения', 'Практикум перевода', 'Биология', 'ОИВТ', 'Черчение', 'Физика', 'МХК', 'Всемирная история', 'Правоведение', 'Русская литература', 'МХК', 'Английский язык', 'Практикум перевода', 'Всемирная история', 'Всемирная история', 'Основы обществоведения', 'Английский язык', 'Практикум по физике', 'Человек и общество']
# В 'School №105' добавлен новый ученик Зосима Денисов, пол 'M', возрат 12, предметы ['Биология и валеология', 'Практикум по физике', 'Правоведение', 'История мира', 'Практика перевода', 'Этика семьи', 'Хореография', 'Информатика', 'Основы обществоведения', 'География', 'Практикум перевода', 'Казахская литература', 'Валеология', 'Основы обществоведения', 'Математика', 'Биология и валеология', 'МХК', 'Казахский язык', 'Казахская литература', 'Практика перевода', 'Математика', 'Английский язык', 'История Казахстана']
#
# Всего добавлено в School №105 => 19 учеников и 3 учителей

# %% [markdown]
# #### **1.4.** Проверка количества созданных объектов классов.
# Количество складывается из всех экземпляров объектов, созданных с начала запуска этого файла 'jupyter notbook'

# %%
print(obj_1.Teacher.count)
print(obj_2.School.count)
print(obj_2.Student.count)
# Out:
# 17
# 3
# 45

# %% [markdown]
# ### **1.5.** Служебные данные для отчёта в классе 'School'

# %%
# список объектов школ, созданных ранее в цикле
print(list_obj_school)
print()

# информация о первом объекте в списке школ
print(list_obj_school[0].get_info)
print()
# Out:
# [<education.organizations.School object at 0x000001E1FCB05F10>, <education.organizations.School object at 0x000001E1FD85A350>, <education.organizations.School object at 0x000001E1FD85A3D0>]
#
# {'id': '0', 'name': 'School №168', 'address': 'ш. Фадеева, д. 848 к. 5/8', 'phone': '89382421948', 'email': 'nikiforovvalerjan@example.net', 'students_count': '95', 'teachers_count': '8', 'tottechr': '6', 'totstud': '12'}

# %% [markdown]
# #### **1.6.** Создание ОТЧЁТА по школам
# Запись информации о школе, учениках и учителях каждой школы в отдельные файлы

# %%
# отчёт по ранее созданным школам
for i in range(len(list_obj_school)):
    list_obj_school[i].get_report
# Out:
# Отчёт по 'School №168' записан в файл './csv/School_№168.csv'
# Отчёт по 'School №51' записан в файл './csv/School_№51.csv'
# Отчёт по 'School №105' записан в файл './csv/School_№105.csv'

# %% [markdown]
# ***

# %% [markdown]
# ***
# ## **2**. Примеры создания самостоятельных объектов, без использования методов класса 'School'

# %% [markdown]
# #### **2.1.** Пример создания объекта класса 'Human'
# Объект создаётся с аргументом, требующим корректировку

# %%
# ПРИМЕР СОЗДАНИЯ ОБЪЕКТА КЛАССА 'Human'
# 1. Объект создаётся, но ошибочно задан 'gender'
hum1 = obj_1.Human("Вася", "Пупкин", 15, "жен", "Казахстан")

# проверка
# print(hum1.gender)

print(hum1.get_name)
print(hum1.get_familyname)
print( hum1.get_age)

print('* =>',hum1.get_gender)     # выделена ошибка

print(hum1.get_nationality)

# изменяется значение поля 'gender'
hum1.set_gender("муж")
print('* =>', hum1.get_gender)
# Out:
# Вася
# Пупкин
# 15
# * => жен
# Казахстан
# * => муж

# %% [markdown]
# #### **2.1.** Пример вывода ошибки при неправильном задании типа аргумента класса
#
# Неправильно задан тип аргумента'age'

# %%
# 2. Неправильно задан тип 'age'
# Выводится сообщение о неправильном типе данных агрумента
hum2 = obj_1.Human("Оля", "Пупкина", "14", "муж", "Казахстан")

print(dir(hum2))
# Out:
# !!!АРГУМЕНТ НЕ СОЗДАН!!!. Аргумент '14' должен быть типа 'int'
# ['_Human__age', '_Human__familyname', '_Human__gender', '_Human__id', '_Human__name', '_Human__nationality', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'count', 'get_age', 'get_familyname', 'get_gender', 'get_info', 'get_name', 'get_nationality', 'set_age', 'set_family', 'set_gender', 'set_name', 'set_nationality']

# %% [markdown]
# #### **1.3.** Несколько вариантов вывода на экран методов объекта класса 'Human'

# %%
# 3. Вывод на экран методов объекта класса 'Human'
print(dir(hum1))
# Out:
# ['_Human__age', '_Human__familyname', '_Human__gender', '_Human__id', '_Human__name', '_Human__nationality', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'count', 'get_age', 'get_familyname', 'get_gender', 'get_info', 'get_name', 'get_nationality', 'set_age', 'set_family', 'set_gender', 'set_name', 'set_nationality']

# %%
hum1.__dict__
# Out:
# {'_Human__name': 'Вася',
#  '_Human__familyname': 'Пупкин',
#  '_Human__age': 15,
#  '_Human__gender': 'муж',
#  '_Human__nationality': 'Казахстан',
#  '_Human__id': 62}

# %%
print(hum1)

print(hum1.get_info)

print(obj_1.Human.count)
# Out:
# Это класс Human
# {'id': 62, 'name': 'Вася', 'familyname': 'Пупкин', 'age': 15, 'gender': 'муж', 'nationality': 'Казахстан'}
# 64

# %% [markdown]
# #### **1.4.** Пример создания самостоятельных объектов класса 'Teacher' без добавления через объект класса 'School'

# %%
# создание объектов 'Teacher'
tch1 = obj_1.Teacher("Алишер", "Навои", 35, "муж", "KZ", "школа №1", ["матем", "казяз"])
tch2 = obj_1.Teacher("Алия", "Жуманова", 60, "жен", "KZ", "школа №2", ["литра", "химия"])

# dir(obj_1.Teacher)


print(tch1.get_info)
print(tch2.get_info)
# Out:
# {'id': '17', 'status': 'учитель', 'name': 'Алишер', 'familyname': 'Навои', 'age': '35', 'gender': 'муж', 'nationality': 'KZ', 'school': 'школа №1', 'subjects': ['матем', 'казяз']}
# {'id': '18', 'status': 'учитель', 'name': 'Алия', 'familyname': 'Жуманова', 'age': '60', 'gender': 'жен', 'nationality': 'KZ', 'school': 'школа №2', 'subjects': ['литра', 'химия']}
